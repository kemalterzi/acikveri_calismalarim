# %%
import pandas as pd
import numpy as np

# %%
yangin_istatistik = pd.read_csv(r"C:\Users\terzi\Desktop\TEMİZ\yangin_istatistik\2020\142_202203_2020yanginistatistik-1.csv" ,sep=";")

# %%
yangin_istatistik.head()
# Out:
#     ilceler  elk._kontak  lpg_d.gaz_vb.  ocak_sob._kalo._kaz.  baca_tut.  \
# 0  SELÇUKLU           76              9                    28          8
# 1     MERAM           73              3                    50         13
# 2   KARATAY           85              7                    28          8
# 3    SANCAK           28              4                     5          1
# 4    AKÖREN            6              0                     3          5
#
#    sig._ve_kibr.  akary.  pat._madd.  yıld._dus.  sabotaj  diger  \
# 0            468       0           0           0       17    112
# 1            574       0           0           0       24    100
# 2            658       0           0           0       28    149
# 3            152       0           0           0        6     42
# 4             20       1           0           0        0      8
#
#    anlasılamadı  tplm
# 0             7   725
# 1            10   847
# 2            10   973
# 3             6   244
# 4            12    55

# %%
yangin_istatistik = yangin_istatistik.rename(columns={'elk._kontak': 'elektrik_kontagi', 'lpg_d.gaz_vb.': 'lpg/dogalgaz', 'ocak_sob._kalo._kaz.': 'ocak/soba/kalorifer/kazan', 'baca_tut.': 'baca_tutusmasi', 'sig._ve_kibr.': 'sigara/kibrit', 'akary.': 'akaryakit', 'pat._madd.': 'patlayici_madde', 'yıld._dus.': 'yildirim_dusmesi', 'anlasılamadı': 'anlasilamadi', 'tplm': 'toplam'})

# %%
yangin_istatistik.head()
# Out:
#     ilceler  elektrik_kontagi  lpg/dogalgaz  ocak/soba/kalorifer/kazan  \
# 0  SELÇUKLU                76             9                         28
# 1     MERAM                73             3                         50
# 2   KARATAY                85             7                         28
# 3    SANCAK                28             4                          5
# 4    AKÖREN                 6             0                          3
#
#    baca_tutusmasi  sigara/kibrit  akaryakit  patlayici_madde  \
# 0               8            468          0                0
# 1              13            574          0                0
# 2               8            658          0                0
# 3               1            152          0                0
# 4               5             20          1                0
#
#    yildirim_dusmesi  sabotaj  diger  anlasilamadi  toplam
# 0                 0       17    112             7     725
# 1                 0       24    100            10     847
# 2                 0       28    149            10     973
# 3                 0        6     42             6     244
# 4                 0        0      8            12      55

# %%
a=yangin_istatistik["elektrik_kontagi"]
b=yangin_istatistik["lpg/dogalgaz"]
c=yangin_istatistik["ocak/soba/kalorifer/kazan"]
d=yangin_istatistik["baca_tutusmasi"]
e=yangin_istatistik["sigara/kibrit"]
f=yangin_istatistik["akaryakit"]
g=yangin_istatistik["patlayici_madde"]
h=yangin_istatistik["yildirim_dusmesi"]
i=yangin_istatistik["sabotaj"]
j=yangin_istatistik["diger"]
k=yangin_istatistik["anlasilamadi"]
l=yangin_istatistik["toplam"]

toplam_saglama=a+b+c+d+e+f+g+h+i+j+k==l
toplam_saglama.head(50)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# dtype: bool

# %%
yangin_istatistik.to_csv(r"C:\Users\terzi\Desktop\yangin_istatistik\2020\csv\yangin_sayi_ve_sebepleri_2020.csv" ,index=False ,header=True)
yangin_istatistik.to_excel(r"C:\Users\terzi\Desktop\yangin_istatistik\2020\excel\yangin_sayi_ve_sebepleri_2020.xlsx" ,index=False ,header=True)
