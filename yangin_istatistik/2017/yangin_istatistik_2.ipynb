# %%
import pandas as pd
import numpy as np

# %%
yangin_istatistik=pd.read_csv(r'C:\Users\terzi\Desktop\temizlenecekler\142_202203_2017yanginistatistik.csv', sep=";")

# %%
yangin_istatistik = yangin_istatistik.rename(columns={'elk._kontak': 'elektrik_kontagi', 'lpg_d.gaz_vb.': 'lpg/dogalgaz', 'ocak_sob._kalo._kaz.': 'ocak/soba/kalorifer/kazan', 'baca_tut.': 'baca_tutusmasi', 'sig._ve_kibr.': 'sigara/kibrit', 'akary.': 'akaryakit', 'pat._madd.': 'patlayici_madde', 'yıld._dus.': 'yildirim_düsmesi', 'anlasılamadı': 'anlasilamadi', 'tplm': 'toplam'})
yangin_istatistik.to_csv(r'C:\Users\terzi\Desktop\temizlenecekler\yangin_istatistik_temiz.csv', index=False)
yangin_istatistik.to_excel(r'C:\Users\terzi\Desktop\temizlenecekler\yangin_istatistik_temiz.xlsx', index=False)

# %%
yangin_istatistik.head()
# Out:
#     ilceler  elektrik_kontagi  lpg/dogalgaz  ocak/soba/kalorifer/kazan  \
# 0  SELÇUKLU               155             7                         20
# 1     MERAM               133             4                         34
# 2   KARATAY                75            11                         18
# 3    SANCAK                 0             0                          0
# 4    AKÖREN                 2             0                          0
#
#    baca_tutusmasi  sigara/kibrit  akaryakit  patlayici_madde  \
# 0              25            533         15                0
# 1              17            301          4                1
# 2              24            441          3                0
# 3               0              0          0                0
# 4               2             24          0                0
#
#    yildirim_düsmesi  sabotaj  diger  anlasilamadi  toplam
# 0                 0       18     31             0     804
# 1                 0        7     16             0     517
# 2                 0       15     23             0     610
# 3                 0        0      0             0       0
# 4                 0        0      7             0      35

# %%
a=yangin_istatistik["elektrik_kontagi"]
b=yangin_istatistik["lpg/dogalgaz"]
c=yangin_istatistik["ocak/soba/kalorifer/kazan"]
d=yangin_istatistik["baca_tutusmasi"]
e=yangin_istatistik["sigara/kibrit"]
f=yangin_istatistik["akaryakit"]
g=yangin_istatistik["patlayici_madde"]
h=yangin_istatistik["yildirim_düsmesi"]
i=yangin_istatistik["sabotaj"]
j=yangin_istatistik["diger"]
k=yangin_istatistik["anlasilamadi"]
l=yangin_istatistik["toplam"]

toplam_saglama=a+b+c+d+e+f+g+h+i+j+k==l
toplam_saglama.head(50)
toplam_saglama.to_excel(r'C:\Users\terzi\Desktop\temizlenecekler\yangin_istatistik_toplam.xlsx', index=False)
