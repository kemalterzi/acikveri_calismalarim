# %%
import pandas as pd
import numpy as np

# %%
yangin_istatistik = pd.read_csv(r"C:\Users\terzi\Desktop\TEMİZ\yangin_istatistik\2019\142_202203_2019yanginistatistik.csv", sep=";")

# %%
yangin_istatistik.head()
# Out:
#     ilceler  elk._kontak  lpg_d.gaz_vb.  ocak_sob._kalo._kaz.  baca_tut.  \
# 0  SELÇUKLU           75              9                    27          9
# 1     MERAM           93              6                    37         14
# 2   KARATAY           77              5                    30          6
# 3    SANCAK           33              1                     6          5
# 4    AKÖREN            3              0                     2          3
#
#    sig._ve_kibr.  akary.  pat._madd.  yıld._dus.  sabotaj  diger  \
# 0            472       0           1           0       24    139
# 1            578       0           0           0       33    143
# 2            724       0           0           0       14    102
# 3            269       0           0           1        3     33
# 4             45       0          13           0        0      3
#
#    anlasılamadı  tplm
# 0            10   766
# 1             2   906
# 2            21   979
# 3            12   363
# 4             0    69

# %%
yangin_istatistik = yangin_istatistik.rename(columns={'elk._kontak': 'elektrik_kontagi', 'lpg_d.gaz_vb.': 'lpg/dogalgaz', 'ocak_sob._kalo._kaz.': 'ocak/soba/kalorifer/kazan', 'baca_tut.': 'baca_tutusmasi', 'sig._ve_kibr.': 'sigara/kibrit', 'akary.': 'akaryakit', 'pat._madd.': 'patlayici_madde', 'yıld._dus.': 'yildirim_dusmesi', 'anlasılamadı': 'anlasilamadi', 'tplm': 'toplam'})

# %%
yangin_istatistik.head()
# Out:
#     ilceler  elektrik_kontagi  lpg/dogalgaz  ocak/soba/kalorifer/kazan  \
# 0  SELÇUKLU                75             9                         27
# 1     MERAM                93             6                         37
# 2   KARATAY                77             5                         30
# 3    SANCAK                33             1                          6
# 4    AKÖREN                 3             0                          2
#
#    baca_tutusmasi  sigara/kibrit  akaryakit  patlayici_madde  \
# 0               9            472          0                1
# 1              14            578          0                0
# 2               6            724          0                0
# 3               5            269          0                0
# 4               3             45          0               13
#
#    yildirim_dusmesi  sabotaj  diger  anlasilamadi  toplam
# 0                 0       24    139            10     766
# 1                 0       33    143             2     906
# 2                 0       14    102            21     979
# 3                 1        3     33            12     363
# 4                 0        0      3             0      69

# %%
a=yangin_istatistik["elektrik_kontagi"]
b=yangin_istatistik["lpg/dogalgaz"]
c=yangin_istatistik["ocak/soba/kalorifer/kazan"]
d=yangin_istatistik["baca_tutusmasi"]
e=yangin_istatistik["sigara/kibrit"]
f=yangin_istatistik["akaryakit"]
g=yangin_istatistik["patlayici_madde"]
h=yangin_istatistik["yildirim_dusmesi"]
i=yangin_istatistik["sabotaj"]
j=yangin_istatistik["diger"]
k=yangin_istatistik["anlasilamadi"]
l=yangin_istatistik["toplam"]

toplam_saglama=a+b+c+d+e+f+g+h+i+j+k==l
toplam_saglama.head(50)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# dtype: bool

# %%
yangin_istatistik.to_csv(r"C:\Users\terzi\Desktop\yangin_istatistik\2019\csv\yangin_sayi_ve_sebepleri_2019.csv" ,index=False ,header=True)
yangin_istatistik.to_excel(r"C:\Users\terzi\Desktop\yangin_istatistik\2019\excel\yangin_sayi_ve_sebepleri_2019.xlsx" ,index=False ,header=True)
