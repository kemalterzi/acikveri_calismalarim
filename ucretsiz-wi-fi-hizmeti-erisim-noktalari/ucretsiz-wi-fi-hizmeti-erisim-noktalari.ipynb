# %%
import pandas as pd
import numpy as np

# %%
wifi = pd.read_csv(r"C:\Users\terzi\Desktop\ucretsiz-wi-fi-hizmeti-erisim-noktalari\d7faec5b-07cc-420f-93b3-7c54a030045d.csv")

# %%
wifi.head()
# Out:
#    _id  no          ucretsiz_wifi_noktalari_adi    1.erisim_koordinat  \
# 0    1   1                      Eski SGK Binası  37.870055, 32.482229
# 1    2   2  Başkanlık Özel Kalem (Alman Evleri)  37.869196, 32.477103
# 2    3   3                     Elkart Müdürlüğü  37.873734, 32.487142
# 3    4   4          Fen İşleri Daire Başkanlığı  37.937266, 32.512032
# 4    5   5                  Millet Kıraathanesi  37.874856, 32.489072
#
#   2._erisim_koordinat
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
wifi = wifi.drop(columns={"_id"})

# %%
wifi.head()
# Out:
#    no          ucretsiz_wifi_noktalari_adi    1.erisim_koordinat  \
# 0   1                      Eski SGK Binası  37.870055, 32.482229
# 1   2  Başkanlık Özel Kalem (Alman Evleri)  37.869196, 32.477103
# 2   3                     Elkart Müdürlüğü  37.873734, 32.487142
# 3   4          Fen İşleri Daire Başkanlığı  37.937266, 32.512032
# 4   5                  Millet Kıraathanesi  37.874856, 32.489072
#
#   2._erisim_koordinat
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
wifi = wifi.drop(columns={"no"})

# %%
pd.options.display.max_rows = None

# %%
wifi.head(90)
# Out:
#                ucretsiz_wifi_noktalari_adi  \
# 0                          Eski SGK Binası
# 1      Başkanlık Özel Kalem (Alman Evleri)
# 2                         Elkart Müdürlüğü
# 3              Fen İşleri Daire Başkanlığı
# 4                      Millet Kıraathanesi
# 5       İrfan Medeniyeti Araştırma Merkezi
# 6                        KültürPark Zabıta
# 7                     Mezar Taşları Müzesi
# 8                   Mevlana Kültür Merkezi
# 9   Park Bahçe Daire Başkanlığı İdari Bina
# 10           Raylı Sistem Daire Başkanlığı
# 11                      Tarımsal Hizmetler
# 12                      Tatlıcak Tesisleri
# 13                        Aydınlık İtfaiye
# 14                           Hayvan Pazarı
# 15                        Kültürpark Kadem
# 16             Kılıçarslan Toplantı Salonu
# 17                        Koyunoğlu Müzesi
# 18                          Sanat Galerisi
# 19                          Hava Hastanesi
# 20                   Ecdat Parkı Müdüriyet
# ...

# %%
wifi[['enlem', 'boylam']] = wifi['1.erisim_koordinat'].astype(str).str.split(', ', expand=True)

# %%
wifi.head()
# Out:
#            ucretsiz_wifi_noktalari_adi    1.erisim_koordinat  \
# 0                      Eski SGK Binası  37.870055, 32.482229
# 1  Başkanlık Özel Kalem (Alman Evleri)  37.869196, 32.477103
# 2                     Elkart Müdürlüğü  37.873734, 32.487142
# 3          Fen İşleri Daire Başkanlığı  37.937266, 32.512032
# 4                  Millet Kıraathanesi  37.874856, 32.489072
#
#   2._erisim_koordinat      enlem     boylam
# 0                 NaN  37.870055  32.482229
# 1                 NaN  37.869196  32.477103
# 2                 NaN  37.873734  32.487142
# 3                 NaN  37.937266  32.512032
# 4                 NaN  37.874856  32.489072

# %%
wifi["boylam"][0]
# Out:
# '32.482229'

# %%
wifi = wifi.drop(columns={"1.erisim_koordinat"})

# %%
wifi.head()
# Out:
#            ucretsiz_wifi_noktalari_adi 2._erisim_koordinat      enlem  \
# 0                      Eski SGK Binası                 NaN  37.870055
# 1  Başkanlık Özel Kalem (Alman Evleri)                 NaN  37.869196
# 2                     Elkart Müdürlüğü                 NaN  37.873734
# 3          Fen İşleri Daire Başkanlığı                 NaN  37.937266
# 4                  Millet Kıraathanesi                 NaN  37.874856
#
#       boylam
# 0  32.482229
# 1  32.477103
# 2  32.487142
# 3  32.512032
# 4  32.489072

# %%
deger = wifi.iloc[33]["ucretsiz_wifi_noktalari_adi"]

# %%
wifi.at[33, "ucretsiz_wifi_noktalari_adi"] = "Japon Parkı"

# %%
yeni_satir = {'ucretsiz_wifi_noktalari_adi': 'Japon Parkı - Kafem', 'enlem': '37.97833965574564', 'boylam': '32.51981645652727'}

# %%
wifi = wifi.append(yeni_satir, ignore_index=True)
# Out:
# C:\Users\terzi\AppData\Local\Temp\ipykernel_13060\847433737.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wifi = wifi.append(yeni_satir, ignore_index=True)

# %%
yeni_satir_2 = {'ucretsiz_wifi_noktalari_adi': 'Kozağaç Park - 2', 'enlem': '37.8057080940925', 'boylam': '32.426848904553644'}

# %%
wifi = wifi.append(yeni_satir_2, ignore_index=True)
# Out:
# C:\Users\terzi\AppData\Local\Temp\ipykernel_13060\1167209760.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wifi = wifi.append(yeni_satir_2, ignore_index=True)

# %%
yeni_satir_3 = {'ucretsiz_wifi_noktalari_adi': 'Kültürpark - 2', 'enlem': '37.87460745936114', 'boylam': '32.4886610455857'}

# %%
wifi = wifi.append(yeni_satir_3, ignore_index=True)
# Out:
# C:\Users\terzi\AppData\Local\Temp\ipykernel_13060\4058454033.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wifi = wifi.append(yeni_satir_3, ignore_index=True)

# %%
yeni_satir_4 = {'ucretsiz_wifi_noktalari_adi': 'Ecdat Parkı Müdüriyet - 2', 'enlem': '37.953332423149085', 'boylam': '32.500958172801525'}

# %%
wifi = wifi.append(yeni_satir_4, ignore_index=True)
# Out:
# C:\Users\terzi\AppData\Local\Temp\ipykernel_13060\2430594209.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wifi = wifi.append(yeni_satir_4, ignore_index=True)

# %%
wifi.tail()
# Out:
#    ucretsiz_wifi_noktalari_adi 2._erisim_koordinat               enlem  \
# 79        Büyükşehir Hastanesi                 NaN           37.878105
# 80         Japon Parkı - Kafem                 NaN   37.97833965574564
# 81            Kozağaç Park - 2                 NaN    37.8057080940925
# 82              Kültürpark - 2                 NaN   37.87460745936114
# 83   Ecdat Parkı Müdüriyet - 2                 NaN  37.953332423149085
#
#                 boylam
# 79           32.488765
# 80   32.51981645652727
# 81  32.426848904553644
# 82    32.4886610455857
# 83  32.500958172801525

# %%
wifi = wifi.drop(columns={"2._erisim_koordinat"})

# %%
wifi.tail()
# Out:
#    ucretsiz_wifi_noktalari_adi               enlem              boylam
# 79        Büyükşehir Hastanesi           37.878105           32.488765
# 80         Japon Parkı - Kafem   37.97833965574564   32.51981645652727
# 81            Kozağaç Park - 2    37.8057080940925  32.426848904553644
# 82              Kültürpark - 2   37.87460745936114    32.4886610455857
# 83   Ecdat Parkı Müdüriyet - 2  37.953332423149085  32.500958172801525

# %%
wifi.to_csv(r"C:\Users\terzi\Desktop\ucretsiz-wi-fi-hizmeti-erisim-noktalari\csv\ucretsiz-Wi-Fi-hizmeti-erisim-noktalari.csv" ,header=True ,index=False)
wifi.to_excel(r"C:\Users\terzi\Desktop\ucretsiz-wi-fi-hizmeti-erisim-noktalari\xlsx\ucretsiz-Wi-Fi-hizmeti-erisim-noktalari.xlsx" ,header=True ,index=False)
